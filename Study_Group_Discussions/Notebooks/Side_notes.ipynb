# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from category_encoders import OneHotEncoder

# %%
df = pd.read_csv("./real-estate-buenos_aires.csv", index_col=False)

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8606 entries, 0 to 8605
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   operation                   8606 non-null   object
#  1   property_type               8606 non-null   object
#  2   place_with_parent_names     8606 non-null   object
#  3   lat-lon                     6936 non-null   object
#  4   price                       7590 non-null   float64
#  5   currency                    7590 non-null   object
#  6   price_aprox_local_currency  7590 non-null   float64
#  7   price_aprox_usd             7590 non-null   float64
#  8   surface_total_in_m2         5946 non-null   float64
#  9   surface_covered_in_m2       7268 non-null   float64
#  10  price_usd_per_m2            4895 non-null   float64
#  11  price_per_m2                6520 non-null   float64
#  12  floor                       1259 non-null   float64
#  13  rooms                       4752 non-null   float64
#  14  expenses                    875 non-null    object
#  15  properati_url               8606 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 1.1+ MB

# %%
df.describe().T
# Out:
#                              count       mean        std  min        25%  \
# price                      7590.00  298207.57  507458.57 0.00   95000.00
# price_aprox_local_currency 7590.00 3591849.41 4758038.25 0.00 1364616.00
# price_aprox_usd            7590.00  236891.88  313805.09 0.00   90000.00
# surface_total_in_m2        5946.00     252.83     938.37 0.00      48.00
# surface_covered_in_m2      7268.00     140.32     764.09 0.00      46.00
# price_usd_per_m2           4895.00    1718.75    1577.02 0.00     916.67
# price_per_m2               6520.00    3732.99   12265.59 2.22    1450.00
# floor                      1259.00       8.80      59.64 1.00       2.00
# rooms                      4752.00       3.07       1.39 1.00       2.00
#
#                                   50%        75%          max
# price                       155000.00  300000.00  11111111.00
# price_aprox_local_currency 2228872.80 4018036.00 121299200.00
# price_aprox_usd             147000.00  265000.00   8000000.00
# surface_total_in_m2             95.00     250.00     62034.00
# surface_covered_in_m2           76.50     160.00     62034.00
# price_usd_per_m2              1600.00    2186.13     54990.00
# price_per_m2                  1961.11    2677.71    450000.00
# floor                            3.00       6.00      1503.00
# rooms                            3.00       4.00        20.00

# %%
df['surface_covered_in_m2'].describe()
# Out:
# count    7268.00
# mean      140.32
# std       764.09
# min         0.00
# 25%        46.00
# 50%        76.50
# 75%       160.00
# max     62034.00
# Name: surface_covered_in_m2, dtype: float64

# %%
plt.hist(df['surface_covered_in_m2'])
plt.xlabel('Area [sq meters]')
plt.title('Distribution of Apartment Sizes')

plt.show()

# %%
new_df = df[
(df['surface_covered_in_m2'] > df['surface_covered_in_m2'].quantile(0.1))
&
(df['surface_covered_in_m2'] < df['surface_covered_in_m2'].quantile(0.9))
]

# %%
plt.hist(new_df['surface_covered_in_m2'])
plt.xlabel('Area [sq meters]')
plt.title('Distribution of Apartment Sizes')

plt.show()

# %%
def wrangle(filepath):
    # Read CSV file
    df = pd.read_csv(filepath)

    # Subset data: Apartments in "Capital Federal", less than 400,000
    mask_ba = df["place_with_parent_names"].str.contains("Capital Federal")
    mask_apt = df["property_type"] == "apartment"
    mask_price = df["price_aprox_usd"] < 400_000
    df = df[mask_ba & mask_apt & mask_price]

    # Subset data: Remove outliers for "surface_covered_in_m2"
    low, high = df["surface_covered_in_m2"].quantile([0.1, 0.9])
    mask_area = df["surface_covered_in_m2"].between(low, high)
    df = df[mask_area]

    # Split "lat-lon" column
    df[["lat", "lon"]] = df["lat-lon"].str.split(",", expand=True).astype(float)
    df.drop(columns="lat-lon", inplace=True)

    # Get place name
    df["neighborhood"] = df["place_with_parent_names"].str.split("|", expand=True)[3]
    df.drop(columns="place_with_parent_names", inplace=True)
    
    # Drop null columns (50%+ null rows)
    nan_cols = nan_columns(df)
    df.drop(columns=nan_cols, inplace=True)
    
    # Drop low- and high-cardinality categorical variables
    df.drop(columns=['operation', 'property_type', 'currency', 'properati_url'], inplace=True)

    # Drop leaky columns
    df.drop(
        columns=['price', 'price_aprox_local_currency', 'price_per_m2', 'price_usd_per_m2'],
        inplace=True
    )
    
    # Drop columns with multicolinearity
    df.drop(columns=['surface_total_in_m2', 'rooms'], inplace=True)
    
    return df

# %%
def nan_columns(df):
    cols_series = df.isnull().sum() / len(df)
    return (cols_series[cols_series >= 0.5]).index

# %%
df = wrangle('./real-estate-buenos_aires.csv')

# %%
ohe = OneHotEncoder(use_cat_names=True)

ohe.fit(df)

df_ae = ohe.transform(df)
print(df_ae.shape)
df_ae.head()
# Out:
# (1343, 57)
#     price_aprox_usd  surface_covered_in_m2    lat    lon  \
# 4         129000.00                  70.00 -34.58 -58.45
# 9          87000.00                  42.00 -34.64 -58.50
# 29        118000.00                  54.00 -34.62 -58.46
# 40         57000.00                  42.00 -34.63 -58.38
# 41         90000.00                  50.00 -34.61 -58.41
#
#     neighborhood_Chacarita  neighborhood_Villa Luro  neighborhood_Caballito  \
# 4                        1                        0                       0
# 9                        0                        1                       0
# 29                       0                        0                       1
# 40                       0                        0                       0
# 41                       0                        0                       0
#
#     neighborhood_Constitución  neighborhood_Once  neighborhood_Almagro  ...  \
# 4                           0                  0                     0  ...
# 9                           0                  0                     0  ...
# 29                          0                  0                     0  ...
# 40                          1                  0                     0  ...
# 41                          0                  1                     0  ...
#
#     neighborhood_Floresta  neighborhood_Retiro  neighborhood_Versalles  \
# 4                       0                    0                       0
# 9                       0                    0                       0
# 29                      0                    0                       0
# 40                      0                    0                       0
# 41                      0                    0                       0
#
#     neighborhood_Boca  neighborhood_Puerto Madero  neighborhood_Agronomía  \
# 4                   0                           0                       0
# 9                   0                           0                       0
# 29                  0                           0                       0
# 40                  0                           0                       0
# 41                  0                           0                       0
#
#     neighborhood_Monte Castro  neighborhood_Tribunales  \
# 4                           0                        0
# 9                           0                        0
# 29                          0                        0
# 40                          0                        0
# 41                          0                        0
#
#     neighborhood_Villa Santa Rita  neighborhood_Velez Sarsfield
# 4                               0                             0
# 9                               0                             0
# 29                              0                             0
# 40                              0                             0
# 41                              0                             0
#
# [5 rows x 57 columns]

# %%
df_ae.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1343 entries, 4 to 8604
# Data columns (total 57 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   price_aprox_usd                   1343 non-null   float64
#  1   surface_covered_in_m2             1343 non-null   float64
#  2   lat                               1300 non-null   float64
#  3   lon                               1300 non-null   float64
#  4   neighborhood_Chacarita            1343 non-null   int64
#  5   neighborhood_Villa_Luro           1343 non-null   int64
#  6   neighborhood_Caballito            1343 non-null   int64
#  7   neighborhood_Constitución         1343 non-null   int64
#  8   neighborhood_Once                 1343 non-null   int64
#  9   neighborhood_Almagro              1343 non-null   int64
#  10  neighborhood_Palermo              1343 non-null   int64
#  11  neighborhood_Flores               1343 non-null   int64
#  12  neighborhood_Belgrano             1343 non-null   int64
#  13  neighborhood_Liniers              1343 non-null   int64
#  14  neighborhood_Villa_Crespo         1343 non-null   int64
#  15  neighborhood_San_Cristobal        1343 non-null   int64
#  16  neighborhood_Congreso             1343 non-null   int64
#  17  neighborhood_Saavedra             1343 non-null   int64
#  18  neighborhood_Balvanera            1343 non-null   int64
#  19  neighborhood_Parque_Avellaneda    1343 non-null   int64
#  20  neighborhood_Recoleta             1343 non-null   int64
#  21  neighborhood_San_Telmo            1343 non-null   int64
#  22  neighborhood_Nuñez                1343 non-null   int64
#  23  neighborhood_Barrio_Norte         1343 non-null   int64
#  24  neighborhood_Parque_Centenario    1343 non-null   int64
#  25  neighborhood_Abasto               1343 non-null   int64
#  26  neighborhood_Centro__Microcentro  1343 non-null   int64
#  27  neighborhood_                     1343 non-null   int64
#  28  neighborhood_Paternal             1343 non-null   int64
#  29  neighborhood_Mataderos            1343 non-null   int64
#  30  neighborhood_Villa_Lugano         1343 non-null   int64
#  31  neighborhood_Coghlan              1343 non-null   int64
#  32  neighborhood_Las_Cañitas          1343 non-null   int64
#  33  neighborhood_Villa_Urquiza        1343 non-null   int64
#  34  neighborhood_Monserrat            1343 non-null   int64
#  35  neighborhood_Villa_Pueyrredón     1343 non-null   int64
#  36  neighborhood_Parque_Patricios     1343 non-null   int64
#  37  neighborhood_San_Nicolás          1343 non-null   int64
#  38  neighborhood_Villa_del_Parque     1343 non-null   int64
#  39  neighborhood_Boedo                1343 non-null   int64
#  40  neighborhood_Parque_Chacabuco     1343 non-null   int64
#  41  neighborhood_Barracas             1343 non-null   int64
#  42  neighborhood_Parque_Chas          1343 non-null   int64
#  43  neighborhood_Colegiales           1343 non-null   int64
#  44  neighborhood_Villa_General_Mitre  1343 non-null   int64
#  45  neighborhood_Villa_Ortuzar        1343 non-null   int64
#  46  neighborhood_Villa_Devoto         1343 non-null   int64
#  47  neighborhood_Floresta             1343 non-null   int64
#  48  neighborhood_Retiro               1343 non-null   int64
#  49  neighborhood_Versalles            1343 non-null   int64
#  50  neighborhood_Boca                 1343 non-null   int64
#  51  neighborhood_Puerto_Madero        1343 non-null   int64
#  52  neighborhood_Agronomía            1343 non-null   int64
#  53  neighborhood_Monte_Castro         1343 non-null   int64
#  54  neighborhood_Tribunales           1343 non-null   int64
#  55  neighborhood_Villa_Santa_Rita     1343 non-null   int64
#  56  neighborhood_Velez_Sarsfield      1343 non-null   int64
# dtypes: float64(4), int64(53)
# memory usage: 608.5 KB

# %%
df_ae.columns = df_ae.columns.str.replace('/', '')

# %%
feature_matrix = df_ae.drop(columns='price_aprox_usd')
target_vector = df_ae['price_aprox_usd']

formula_str = target_vector.name + ' ~ ' + ' + '.join(feature_matrix)

model = smf.ols(formula=formula_str, data=df_ae)

fitted = model.fit()

print(fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        price_aprox_usd   R-squared:                       0.695
# Model:                            OLS   Adj. R-squared:                  0.681
# Method:                 Least Squares   F-statistic:                     51.51
# Date:                Thu, 04 Apr 2024   Prob (F-statistic):          1.36e-278
# Time:                        18:48:55   Log-Likelihood:                -15363.
# No. Observations:                1300   AIC:                         3.084e+04
# Df Residuals:                    1244   BIC:                         3.113e+04
# Df Model:                          55
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept
# neighborhood_Villa_Pueyrredón     5.352e+05   1.28e+05      4.183      0.000    2.84e+05    7.86e+05
# neighborhood_Parque_Patricios     5.416e+05   1.27e+05      4.278      0.000    2.93e+05     7.9e+05
# neighborhood_San_Nicolás          5.137e+05   1.22e+05      4.198      0.000    2.74e+05    7.54e+05
# neighborhood_Villa_del_Parque     5.437e+05   1.29e+05      4.223      0.000    2.91e+05    7.96e+05
# neighborhood_Boedo                5.505e+05   1.27e+05      4.334      0.000    3.01e+05       8e+05
# neighborhood_Parque_Chacabuco     5.398e+05    1.3e+05      4.164      0.000    2.85e+05    7.94e+05
# neighborhood_Barracas             5.382e+05   1.25e+05      4.306      0.000    2.93e+05    7.83e+05
# neighborhood_Parque_Chas          5.423e+05   1.28e+05      4.242      0.000    2.92e+05    7.93e+05
# neighborhood_Colegiales           5.618e+05   1.24e+05      4.524      0.000    3.18e+05    8.06e+05
# neighborhood_Villa_General_Mitre  5.196e+05   1.29e+05      4.018      0.000    2.66e+05    7.73e+05
# neighborhood_Villa_Ortuzar        5.347e+05   1.25e+05      4.267      0.000    2.89e+05    7.81e+05
# neighborhood_Villa_Devoto          5.53e+05    1.3e+05      4.265      0.000    2.99e+05    8.07e+05
# neighborhood_Floresta             5.387e+05   1.31e+05      4.098      0.000    2.81e+05    7.97e+05
# neighborhood_Retiro               5.502e+05   1.22e+05      4.507      0.000    3.11e+05     7.9e+05
# neighborhood_Versalles            5.509e+05   1.36e+05      4.065      0.000    2.85e+05    8.17e+05
# neighborhood_Boca                 5.086e+05   1.24e+05      4.091      0.000    2.65e+05    7.52e+05
# neighborhood_Puerto_Madero         6.71e+05   1.23e+05      5.472      0.000     4.3e+05    9.12e+05
# neighborhood_Agronomía            5.585e+05   1.28e+05      4.349      0.000    3.07e+05     8.1e+05
# neighborhood_Monte_Castro         5.475e+05   1.32e+05      4.153      0.000    2.89e+05    8.06e+05
# neighborhood_Tribunales            5.44e+05   1.24e+05      4.377      0.000       3e+05    7.88e+05
# neighborhood_Villa_Santa_Rita     5.401e+05    1.3e+05      4.141      0.000    2.84e+05    7.96e+05
# neighborhood_Velez_Sarsfield      5.407e+05   1.35e+05      3.997      0.000    2.75e+05    8.06e+05
# ==============================================================================
# Omnibus:                      213.914   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              490.204
# Skew:                           0.918   Prob(JB):                    3.58e-107
# Kurtosis:                       5.383   Cond. No.                     2.27e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.96e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
sns.scatterplot(fitted.resid)
# Out:
# <Axes: >

# %%
pd.read_csv('http://cox.csueastbay.edu/~esuess/classes/Statistics_452/Presentations/ml10a/insurance.csv')
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female 27.90         0    yes  southwest  16884.92
# 1      18    male 33.80         1     no  southeast   1725.55
# 2      28    male 33.00         3     no  southeast   4449.46
# 3      33    male 22.70         0     no  northwest  21984.47
# 4      32    male 28.90         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male 31.00         3     no  northwest  10600.55
# 1334   18  female 31.90         0     no  northeast   2205.98
# 1335   18  female 36.90         0     no  southeast   1629.83
# 1336   21  female 25.80         0     no  southwest   2007.95
# 1337   61  female 29.10         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]
